# %%
import re
from collections import Counter

import numpy as np
import pandas as pd

import matplotlib, matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from mpl_toolkits.mplot3d import axes3d
# %matplotlib inline
import seaborn as sns

import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn.neighbors import KernelDensity

# from xgboost.sklearn import XGBClassifier as XGBC

# from bayes_opt import BayesianOptimization
import scipy
from scipy import stats
import statsmodels.api as sm

from sklearn.impute import KNNImputer
from sklearn.decomposition import PCA, MiniBatchSparsePCA
from sklearn.manifold import TSNE
import sweetviz as sv
from sklearn.decomposition import KernelPCA

# %% [markdown]
# ### Vizualizing Raw data to check missing data and possible correlations

# %%
dataset = pd.read_csv("CHES2019_experts.csv")

# %%
chapel_hill_survey = sv.analyze(dataset)
chapel_hill_survey.show_html("chapel_hill_survey.html")
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, layout=Layout(flex='2'), max=64.0), HTML(value='')), l…
# Report chapel_hill_survey.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Part I Preprocessing Data

# %%
df = pd.read_csv("CHES2019_experts.csv")

# %%
df.head(20)
# Out:
#     id  party      party_name  party_id  position  eu_salience  eu_dissent  \
# 0    1      1            GERB      2010       7.0          9.0         1.0
# 1    1      2             BSP      2003       5.0          6.0         4.0
# 2    1      3             DPS      2004       7.0          9.0         2.0
# 3    1      4           Volya      2017       3.0          6.0         4.0
# 4    1      5            NFSB      2014       3.0          6.0         4.0
# 5    1      6           Ataka      2007       3.0          6.0         4.0
# 6    1      7            BMRO      2005       5.0          6.0         2.0
# 7    1      8              DB      2018       7.0         10.0         0.0
# 8    1      9             DSB      2008       7.0         10.0         0.0
# 9    1     10  Slavi Trifonov      2019       6.0          9.0         1.0
# 10   2      1            GERB      2010       5.0          7.0         3.0
# 11   2      2             BSP      2003       3.0          6.0         7.0
# 12   2      3             DPS      2004       5.0          6.0         0.0
# 13   2      4           Volya      2017       2.0          4.0         1.0
# 14   2      5            NFSB      2014       3.0          4.0         2.0
# 15   2      6           Ataka      2007       1.0          7.0         0.0
# 16   2      7            BMRO      2005       3.0          5.0         2.0
# 17   2      8              DB      2018       7.0          8.0         3.0
# 18   2      9             DSB      2008       6.0          7.0         3.0
# 19   2     10  Slavi Trifonov      2019       5.0          3.0         NaN
#
#     eu_blur lrecon lrecon_blur  ...     dob  lrecon_self galtan_self  cname  \
# 0       NaN      5         NaN  ...  1948.0          9.0         3.0    NaN
# 1       NaN      3         NaN  ...  1948.0          9.0         3.0    NaN
# 2       NaN      5         NaN  ...  1948.0          9.0         3.0    NaN
# 3       NaN      7         NaN  ...  1948.0          9.0         3.0    NaN
# 4       NaN      7         NaN  ...  1948.0          9.0         3.0    NaN
# 5       NaN      3         NaN  ...  1948.0          9.0         3.0    NaN
# 6       NaN      4         NaN  ...  1948.0          9.0         3.0    NaN
# 7       NaN      9         NaN  ...  1948.0          9.0         3.0    NaN
# 8       NaN      9         NaN  ...  1948.0          9.0         3.0    NaN
# 9       NaN      5         NaN  ...  1948.0          9.0         3.0    NaN
# 10      NaN      5         NaN  ...  1972.0          7.0         3.0    NaN
# 11      NaN      5         NaN  ...  1972.0          7.0         3.0    NaN
# 12      NaN      5         NaN  ...  1972.0          7.0         3.0    NaN
# 13      NaN      6         NaN  ...  1972.0          7.0         3.0    NaN
# 14      NaN      4         NaN  ...  1972.0          7.0         3.0    NaN
# 15      NaN      2         NaN  ...  1972.0          7.0         3.0    NaN
# 16      NaN      5         NaN  ...  1972.0          7.0         3.0    NaN
# 17      NaN      8         NaN  ...  1972.0          7.0         3.0    NaN
# 18      NaN      8         NaN  ...  1972.0          7.0         3.0    NaN
# 19      NaN      5         NaN  ...  1972.0          7.0         3.0    NaN
#
#     eu_position_sd  lrecon_sd  galtan_sd  eu_econ_require  \
# 0              NaN        NaN        NaN              NaN
# 1              NaN        NaN        NaN              NaN
# 2              NaN        NaN        NaN              NaN
# 3              NaN        NaN        NaN              NaN
# 4              NaN        NaN        NaN              NaN
# 5              NaN        NaN        NaN              NaN
# 6              NaN        NaN        NaN              NaN
# 7              NaN        NaN        NaN              NaN
# 8              NaN        NaN        NaN              NaN
# 9              NaN        NaN        NaN              NaN
# 10             NaN        NaN        NaN              NaN
# 11             NaN        NaN        NaN              NaN
# 12             NaN        NaN        NaN              NaN
# 13             NaN        NaN        NaN              NaN
# 14             NaN        NaN        NaN              NaN
# 15             NaN        NaN        NaN              NaN
# 16             NaN        NaN        NaN              NaN
# 17             NaN        NaN        NaN              NaN
# 18             NaN        NaN        NaN              NaN
# 19             NaN        NaN        NaN              NaN
#
#     eu_political_require  eu_googov_require
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4                    NaN                NaN
# 5                    NaN                NaN
# 6                    NaN                NaN
# 7                    NaN                NaN
# 8                    NaN                NaN
# 9                    NaN                NaN
# 10                   NaN                NaN
# 11                   NaN                NaN
# 12                   NaN                NaN
# 13                   NaN                NaN
# 14                   NaN                NaN
# 15                   NaN                NaN
# 16                   NaN                NaN
# 17                   NaN                NaN
# 18                   NaN                NaN
# 19                   NaN                NaN
#
# [20 rows x 63 columns]

# %%
df.columns
# Out:
# Index(['id', 'party', 'party_name', 'party_id', 'position', 'eu_salience',
#        'eu_dissent', 'eu_blur', 'lrecon', 'lrecon_blur', 'lrecon_dissent',
#        'lrecon_salience', 'galtan', 'galtan_blur', 'galtan_dissent',
#        'galtan_salience', 'lrgen', 'immigrate_policy', 'immigra_salience',
#        'immigrate_dissent', 'multiculturalism', 'multicult_salience',
#        'multicult_dissent', 'redistribution', 'redist_salience', 'environment',
#        'enviro_salience', 'spendvtax', 'deregulation', 'econ_interven',
#        'civlib_laworder', 'sociallifestyle', 'religious_principles',
#        'ethnic_minorities', 'nationalism', 'urban_rural', 'protectionism',
#        'regions', 'russian_interference', 'anti_islam_rhetoric',
#        'people_vs_elite', 'antielite_salience', 'corrupt_salience',
#        'members_vs_leadership', 'eu_cohesion', 'eu_foreign', 'eu_intmark',
#        'eu_budgets', 'eu_asylum', 'party_a_econ', 'party_b_econ',
#        'party_c_econ', 'gender', 'dob', 'lrecon_self', 'galtan_self', 'cname',
#        'eu_position_sd', 'lrecon_sd', 'galtan_sd', 'eu_econ_require',
#        'eu_political_require', 'eu_googov_require'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 id        party     party_id     position  eu_salience  \
# count  3823.000000  3823.000000  3823.000000  3561.000000  3523.000000
# mean      8.643735     5.353387  1864.380068     4.971637     6.085722
# std       5.668377     3.102622  1100.263807     1.933308     2.457828
# min       1.000000     1.000000   102.000000     1.000000     0.000000
# 25%       4.000000     3.000000   837.000000     3.000000     4.000000
# 50%       8.000000     5.000000  2101.000000     6.000000     6.000000
# 75%      12.000000     8.000000  2804.000000     7.000000     8.000000
# max      27.000000    14.000000  4508.000000     7.000000    10.000000
#
#         eu_dissent      eu_blur  lrecon_dissent  lrecon_salience  galtan_blur  \
# count  1499.000000  1802.000000     1520.000000      3523.000000  1642.000000
# mean      2.625751     3.146504        2.960526         6.355095     2.783800
# std       2.217037     2.596855        2.136185         2.253446     2.422755
# min       0.000000     0.000000        0.000000         0.000000     0.000000
# 25%       1.000000     1.000000        1.000000         5.000000     1.000000
# 50%       2.000000     3.000000        2.000000         7.000000     2.000000
# 75%       4.000000     5.000000        4.000000         8.000000     4.000000
# max      10.000000    10.000000       10.000000        10.000000    10.000000
#
#        ...       gender          dob  lrecon_self  galtan_self  \
# count  ...  3814.000000  3674.000000  3797.000000  3799.000000
# mean   ...     1.710016  1972.347033     4.918093     3.326402
# std    ...     0.477470    12.658841     1.885663     1.808154
# min    ...     1.000000  1933.000000     1.000000     1.000000
# 25%    ...     1.000000  1963.000000     4.000000     2.000000
# 50%    ...     2.000000  1975.000000     5.000000     3.000000
# 75%    ...     2.000000  1982.000000     6.000000     4.000000
# max    ...     3.000000  1995.000000    11.000000    11.000000
#
#        eu_position_sd    lrecon_sd    galtan_sd  eu_econ_require  \
# count     1989.000000  1989.000000  1989.000000        36.000000
# mean         0.772500     1.028167     1.420311         4.916667
# std          0.347610     0.488534     0.607744         1.401530
# min          0.000000     0.000000     0.000000         1.000000
# 25%          0.534522     0.690066     0.997249         4.000000
# 50%          0.707107     0.900337     1.264911         5.000000
# 75%          0.971825     1.193416     1.772104         6.000000
# max          2.121320     3.535534     3.681518         7.000000
#
#        eu_political_require  eu_googov_require
# count             43.000000          38.000000
# mean               4.186047           4.552632
# std                2.442245           2.344601
# min                1.000000           1.000000
# 25%                2.000000           2.250000
# 50%                5.000000           5.000000
# 75%                7.000000           7.000000
# max                7.000000           7.000000
#
# [8 rows x 56 columns]

# %% [markdown]
# #### Dropping columns that have large missing values

# %%
# dropping >95% missing data columns
df.drop(columns = ["eu_econ_require", "eu_political_require", "eu_googov_require"], inplace=True)

# %%
#dropping party_name column as we have the unique identifier party_id
df.drop(columns="party_name", inplace=True)
df
# Out:
#       id  party  party_id  position  eu_salience  eu_dissent  eu_blur lrecon  \
# 0      1      1      2010       7.0          9.0         1.0      NaN      5
# 1      1      2      2003       5.0          6.0         4.0      NaN      3
# 2      1      3      2004       7.0          9.0         2.0      NaN      5
# 3      1      4      2017       3.0          6.0         4.0      NaN      7
# 4      1      5      2014       3.0          6.0         4.0      NaN      7
# ...   ..    ...       ...       ...          ...         ...      ...    ...
# 3818  17      8      1110       1.0          8.0         NaN      1.0     .d
# 3819   4      8      1110       1.0         10.0         0.0      NaN      8
# 3820  11      8      1110       NaN          NaN         NaN      NaN     .d
# 3821  16      8      1110       2.0          5.0         NaN      3.0      8
# 3822   3      8      1110       2.0         10.0         7.0      NaN      8
#
#      lrecon_blur  lrecon_dissent  ...  party_b_econ party_c_econ  gender  \
# 0            NaN             1.0  ...             9          6.0     1.0
# 1            NaN             5.0  ...             9          6.0     1.0
# 2            NaN             1.0  ...             9          6.0     1.0
# 3            NaN             5.0  ...             9          6.0     1.0
# 4            NaN             5.0  ...             9          6.0     1.0
# ...          ...             ...  ...           ...          ...     ...
# 3818         NaN             NaN  ...             9          5.0     2.0
# 3819           1             NaN  ...            10          7.0     2.0
# 3820          .d             NaN  ...             9          5.0     1.0
# 3821          .d             NaN  ...             8          5.0     1.0
# 3822         NaN             6.0  ...             9          5.0     2.0
#
#          dob  lrecon_self  galtan_self  cname  eu_position_sd  lrecon_sd  \
# 0     1948.0          9.0          3.0    NaN             NaN        NaN
# 1     1948.0          9.0          3.0    NaN             NaN        NaN
# 2     1948.0          9.0          3.0    NaN             NaN        NaN
# 3     1948.0          9.0          3.0    NaN             NaN        NaN
# 4     1948.0          9.0          3.0    NaN             NaN        NaN
# ...      ...          ...          ...    ...             ...        ...
# 3818  1976.0          5.0          3.0     uk        1.087811   1.964971
# 3819  1959.0          6.0          3.0     uk        1.087811   1.964971
# 3820  1990.0          3.0          2.0     uk        1.087811   1.964971
# 3821  1977.0          5.0          3.0     uk        1.087811   1.964971
# 3822  1940.0          2.0          4.0     uk        1.087811   1.964971
#
#       galtan_sd
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 3818   1.192928
# 3819   1.192928
# 3820   1.192928
# 3821   1.192928
# 3822   1.192928
#
# [3823 rows x 59 columns]

# %%
# making party_id as a target as we want to represent political parties in two dimensions
target = df["party_id"]
target.value_counts()
# Out:
# 2101    27
# 2103    27
# 2109    27
# 2111    27
# 2115    27
#         ..
# 4004     2
# 3802     2
# 3804     2
# 3806     2
# 4009     2
# Name: party_id, Length: 277, dtype: int64

# %%
#dropping cname, eu_position_sd, lrecon_sd, galtan_sd > 50% values missing
df.drop(columns=["cname", "eu_position_sd", "lrecon_sd", "galtan_sd"], inplace=True)
df.head()
# Out:
#    id  party  party_id  position  eu_salience  eu_dissent  eu_blur lrecon  \
# 0   1      1      2010       7.0          9.0         1.0      NaN      5
# 1   1      2      2003       5.0          6.0         4.0      NaN      3
# 2   1      3      2004       7.0          9.0         2.0      NaN      5
# 3   1      4      2017       3.0          6.0         4.0      NaN      7
# 4   1      5      2014       3.0          6.0         4.0      NaN      7
#
#   lrecon_blur  lrecon_dissent  ...  eu_intmark eu_budgets  eu_asylum  \
# 0         NaN             1.0  ...         7.0        7.0        4.0
# 1         NaN             5.0  ...         3.0        3.0        4.0
# 2         NaN             1.0  ...         7.0        7.0        6.0
# 3         NaN             5.0  ...         7.0        4.0        3.0
# 4         NaN             5.0  ...         7.0        5.0        3.0
#
#    party_a_econ  party_b_econ  party_c_econ  gender     dob  lrecon_self  \
# 0           3.0             9           6.0     1.0  1948.0          9.0
# 1           3.0             9           6.0     1.0  1948.0          9.0
# 2           3.0             9           6.0     1.0  1948.0          9.0
# 3           3.0             9           6.0     1.0  1948.0          9.0
# 4           3.0             9           6.0     1.0  1948.0          9.0
#
#    galtan_self
# 0          3.0
# 1          3.0
# 2          3.0
# 3          3.0
# 4          3.0
#
# [5 rows x 55 columns]

# %% [markdown]
# #### Replacing the value ".d" with mode (most frequent values)

# %%
#replacing all the columns that have value ".d" with mode (most frequent value)
for col in df.columns:
    df[col].loc[df[col] == ".d"] = df[col].mode()
# Out:
# /Users/stuti/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
# df["lrecon_blur"].loc[df["lrecon_blur"] == ".d"] = df["lrecon_blur"].mode()
df["lrecon_blur"].value_counts()
# Out:
# 2     263
# 3     249
# 1     247
# 4     212
# 0     187
# 5     181
# 6     146
# 7     143
# 8      90
# 10     29
# 9      29
# Name: lrecon_blur, dtype: int64

# %% [markdown]
# ### Feature engineering
# 1. Separating the column "gender" and "dob": the preprocessing needs to be different than other columns
# 2. Dropping the columns following columns:
#
#     a. "id": It is unclear in the documentation what it represents
#
#     b. "party": we are interested in the party projections, so there is no requirement to keep additional information for the same
#
#     c. "party_id": since it is a target so it is not included in the feature matrix

# %%
features = df.drop(columns=["id", "party", "party_id", "gender", "dob"])
features
# Out:
#       position  eu_salience  eu_dissent  eu_blur lrecon lrecon_blur  \
# 0          7.0          9.0         1.0      NaN      5         NaN
# 1          5.0          6.0         4.0      NaN      3         NaN
# 2          7.0          9.0         2.0      NaN      5         NaN
# 3          3.0          6.0         4.0      NaN      7         NaN
# 4          3.0          6.0         4.0      NaN      7         NaN
# ...        ...          ...         ...      ...    ...         ...
# 3818       1.0          8.0         NaN      1.0    NaN         NaN
# 3819       1.0         10.0         0.0      NaN      8           1
# 3820       NaN          NaN         NaN      NaN    NaN         NaN
# 3821       2.0          5.0         NaN      3.0      8         NaN
# 3822       2.0         10.0         7.0      NaN      8         NaN
#
#       lrecon_dissent  lrecon_salience galtan  galtan_blur  ...  eu_cohesion  \
# 0                1.0             10.0      6          NaN  ...          7.0
# 1                5.0              7.0      9          NaN  ...          7.0
# 2                1.0              9.0      5          NaN  ...          7.0
# 3                5.0              9.0      9          NaN  ...          7.0
# 4                5.0              5.0      9          NaN  ...          7.0
# ...              ...              ...    ...          ...  ...          ...
# 3818             NaN              NaN      8          1.0  ...          NaN
# 3819             NaN              5.0    NaN          NaN  ...          NaN
# 3820             NaN              NaN    NaN          NaN  ...          NaN
# 3821             NaN              NaN     10          NaN  ...          1.0
# 3822             6.0              NaN      9          1.0  ...          7.0
#
#       eu_foreign  eu_intmark  eu_budgets  eu_asylum  party_a_econ  \
# 0            7.0         7.0         7.0        4.0           3.0
# 1            4.0         3.0         3.0        4.0           3.0
# 2            6.0         7.0         7.0        6.0           3.0
# 3            4.0         7.0         4.0        3.0           3.0
# 4            5.0         7.0         5.0        3.0           3.0
# ...          ...         ...         ...        ...           ...
# 3818         NaN         4.0         2.0        2.0           3.0
# 3819         NaN         NaN         NaN        NaN           2.0
# 3820         NaN         NaN         NaN        NaN           3.0
# 3821         1.0         1.0         1.0        1.0           3.0
# 3822         1.0         4.0         1.0        1.0           3.0
#
#       party_b_econ  party_c_econ  lrecon_self  galtan_self
# 0                9           6.0          9.0          3.0
# 1                9           6.0          9.0          3.0
# 2                9           6.0          9.0          3.0
# 3                9           6.0          9.0          3.0
# 4                9           6.0          9.0          3.0
# ...            ...           ...          ...          ...
# 3818             9           5.0          5.0          3.0
# 3819            10           7.0          6.0          3.0
# 3820             9           5.0          3.0          2.0
# 3821             8           5.0          5.0          3.0
# 3822             9           5.0          2.0          4.0
#
# [3823 rows x 50 columns]

# %% [markdown]
# #### Preprocessing the "dob"
# Binning the date of birth column: Range = [1933, 1995]
#
# 1930 - 1940: 0
#
# 1940 - 1950: 2
#
# .
# .
# .
#
# 1990 - 2000: 6

# %%
df["dob_bins"] = pd.cut(x = df["dob"], bins = [1930.0, 1940.0, 1950.0, 1960.0, 1970.0, 1980.0, 1990.0, 2000.0], 
                        labels=range(7))

# %%
df["dob_bins"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3818    4
# 3819    2
# 3820    5
# 3821    4
# 3822    0
# Name: dob_bins, Length: 3823, dtype: category
# Categories (7, int64): [0 < 1 < 2 < 3 < 4 < 5 < 6]

# %%
# filling missing values with mode (most frequent values)
df["gender"].fillna(df["gender"].mode()[0], inplace=True)
df["gender"].value_counts()
# Out:
# 2.0    2633
# 1.0    1148
# 3.0      42
# Name: gender, dtype: int64

# %%
# imputating the missing values with mode
df["dob_bins"].fillna(df["dob_bins"].mode()[0], inplace=True)
df["dob_bins"].value_counts()
# Out:
# 4    1390
# 5     998
# 3     591
# 2     474
# 1     238
# 6      95
# 0      37
# Name: dob_bins, dtype: int64

# %%
# concatenating the column "dob" and "gender" to the feature matrix
features = pd.concat([features, df["gender"], df["dob_bins"]], axis = 1)
features
# Out:
#       position  eu_salience  eu_dissent  eu_blur lrecon lrecon_blur  \
# 0          7.0          9.0         1.0      NaN      5         NaN
# 1          5.0          6.0         4.0      NaN      3         NaN
# 2          7.0          9.0         2.0      NaN      5         NaN
# 3          3.0          6.0         4.0      NaN      7         NaN
# 4          3.0          6.0         4.0      NaN      7         NaN
# ...        ...          ...         ...      ...    ...         ...
# 3818       1.0          8.0         NaN      1.0    NaN         NaN
# 3819       1.0         10.0         0.0      NaN      8           1
# 3820       NaN          NaN         NaN      NaN    NaN         NaN
# 3821       2.0          5.0         NaN      3.0      8         NaN
# 3822       2.0         10.0         7.0      NaN      8         NaN
#
#       lrecon_dissent  lrecon_salience galtan  galtan_blur  ...  eu_intmark  \
# 0                1.0             10.0      6          NaN  ...         7.0
# 1                5.0              7.0      9          NaN  ...         3.0
# 2                1.0              9.0      5          NaN  ...         7.0
# 3                5.0              9.0      9          NaN  ...         7.0
# 4                5.0              5.0      9          NaN  ...         7.0
# ...              ...              ...    ...          ...  ...         ...
# 3818             NaN              NaN      8          1.0  ...         4.0
# 3819             NaN              5.0    NaN          NaN  ...         NaN
# 3820             NaN              NaN    NaN          NaN  ...         NaN
# 3821             NaN              NaN     10          NaN  ...         1.0
# 3822             6.0              NaN      9          1.0  ...         4.0
#
#       eu_budgets  eu_asylum  party_a_econ  party_b_econ  party_c_econ  \
# 0            7.0        4.0           3.0             9           6.0
# 1            3.0        4.0           3.0             9           6.0
# 2            7.0        6.0           3.0             9           6.0
# 3            4.0        3.0           3.0             9           6.0
# 4            5.0        3.0           3.0             9           6.0
# ...          ...        ...           ...           ...           ...
# 3818         2.0        2.0           3.0             9           5.0
# 3819         NaN        NaN           2.0            10           7.0
# 3820         NaN        NaN           3.0             9           5.0
# 3821         1.0        1.0           3.0             8           5.0
# 3822         1.0        1.0           3.0             9           5.0
#
#       lrecon_self  galtan_self  gender  dob_bins
# 0             9.0          3.0     1.0         1
# 1             9.0          3.0     1.0         1
# 2             9.0          3.0     1.0         1
# 3             9.0          3.0     1.0         1
# 4             9.0          3.0     1.0         1
# ...           ...          ...     ...       ...
# 3818          5.0          3.0     2.0         4
# 3819          6.0          3.0     2.0         2
# 3820          3.0          2.0     1.0         5
# 3821          5.0          3.0     1.0         4
# 3822          2.0          4.0     2.0         0
#
# [3823 rows x 52 columns]

# %%
features.dtypes
# Out:
# position                  float64
# eu_salience               float64
# eu_dissent                float64
# eu_blur                   float64
# lrecon                     object
# lrecon_blur                object
# lrecon_dissent            float64
# lrecon_salience           float64
# galtan                     object
# galtan_blur               float64
# galtan_dissent            float64
# galtan_salience           float64
# lrgen                     float64
# immigrate_policy          float64
# immigra_salience          float64
# immigrate_dissent         float64
# multiculturalism          float64
# multicult_salience        float64
# multicult_dissent         float64
# redistribution            float64
# redist_salience           float64
# environment               float64
# enviro_salience           float64
# spendvtax                 float64
# deregulation              float64
# econ_interven             float64
# civlib_laworder           float64
# sociallifestyle           float64
# religious_principles      float64
# ethnic_minorities         float64
# nationalism               float64
# urban_rural               float64
# protectionism             float64
# regions                   float64
# russian_interference      float64
# anti_islam_rhetoric        object
# people_vs_elite           float64
# antielite_salience        float64
# corrupt_salience          float64
# members_vs_leadership     float64
# eu_cohesion               float64
# eu_foreign                float64
# eu_intmark                float64
# eu_budgets                float64
# eu_asylum                 float64
# party_a_econ              float64
# party_b_econ               object
# party_c_econ              float64
# lrecon_self               float64
# galtan_self               float64
# gender                    float64
# dob_bins                 category
# dtype: object

# %% [markdown]
# #### Impute missing data
# 1) for categorical data (object or ints), use the most frequent value (mode)
#
# 2) for continuous values (floats), use the median

# %%
for column in features.columns:
    if features[column].dtype == "object" or features[column].dtype == 'int64':
        features[column].fillna(features[column].mode()[0], inplace=True)
    elif features[column].dtype == "float64":
        features[column].fillna(features[column].median(), inplace=True)

# %%
features.head()
# Out:
#    position  eu_salience  eu_dissent  eu_blur lrecon lrecon_blur  \
# 0       7.0          9.0         1.0      3.0      5           2
# 1       5.0          6.0         4.0      3.0      3           2
# 2       7.0          9.0         2.0      3.0      5           2
# 3       3.0          6.0         4.0      3.0      7           2
# 4       3.0          6.0         4.0      3.0      7           2
#
#    lrecon_dissent  lrecon_salience galtan  galtan_blur  ...  eu_intmark  \
# 0             1.0             10.0      6          2.0  ...         7.0
# 1             5.0              7.0      9          2.0  ...         3.0
# 2             1.0              9.0      5          2.0  ...         7.0
# 3             5.0              9.0      9          2.0  ...         7.0
# 4             5.0              5.0      9          2.0  ...         7.0
#
#    eu_budgets  eu_asylum  party_a_econ  party_b_econ  party_c_econ  \
# 0         7.0        4.0           3.0             9           6.0
# 1         3.0        4.0           3.0             9           6.0
# 2         7.0        6.0           3.0             9           6.0
# 3         4.0        3.0           3.0             9           6.0
# 4         5.0        3.0           3.0             9           6.0
#
#    lrecon_self  galtan_self  gender  dob_bins
# 0          9.0          3.0     1.0         1
# 1          9.0          3.0     1.0         1
# 2          9.0          3.0     1.0         1
# 3          9.0          3.0     1.0         1
# 4          9.0          3.0     1.0         1
#
# [5 rows x 52 columns]

# %% [markdown]
# # Part II Dimensionality Reduction
#
# 1. Since, the scale of data is not uniform therefore, scaling the data to  a uniform range with the help of StandardScaler()
#
# 2. Perform dimensionality reduction using Principal Component Analysis (PCA)

# %%
#scaling using standard scalar
data_scaler = preprocessing.StandardScaler()
data_scaler.fit(features)
# Out:
# StandardScaler()

# %%
scaled_data_frame = data_scaler.transform(features)
scaled_data_frame
# Out:
# array([[ 1.03942282,  1.23813358, -0.87637798, ..., -0.17995428,
#         -1.48977186, -2.10419409],
#        [-0.02235766, -0.03348405,  1.23477074, ..., -0.17995428,
#         -1.48977186, -2.10419409],
#        [ 1.03942282,  1.23813358, -0.17266174, ..., -0.17995428,
#         -1.48977186, -2.10419409],
#        ...,
#        [ 0.50853258, -0.03348405, -0.17266174, ..., -0.73476495,
#         -1.48977186,  1.03322167],
#        [-1.61502838, -0.45735659, -0.17266174, ..., -0.17995428,
#         -1.48977186,  0.24886773],
#        [-1.61502838,  1.66200612,  3.34591947, ...,  0.37485638,
#          0.60643639, -2.88854803]])

# %%
pca_2 = PCA(n_components=2).fit(scaled_data_frame)
df_pca_2 = pca_2.transform(scaled_data_frame)

# %%
pca_2.explained_variance_ratio_
# Out:
# array([0.21268321, 0.10649313])

# %%
plt.figure(figsize = (16,8))
plt.scatter(df_pca_2[:, 0], df_pca_2[:, 1], c = target)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.colorbar()

# %%
print(df_pca_2.shape)
print(scaled_data_frame.shape)
# Out:
# (3823, 2)
# (3823, 52)

# %% [markdown]
# #### Gathering the most important feature on EACH component
# In order to understand what factors matter the most in the political landscape

# %%
n_pcs = pca_2.components_.shape[0]

# %%
most_important = [np.abs(pca_2.components_[i]).argmax() for i in range(n_pcs)]

initial_feature_names = features.columns
# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]

dic = {'PC{}'.format(i): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
pc_df = pd.DataFrame(dic.items())
pc_df
# Out:
#      0             1
# 0  PC0   nationalism
# 1  PC1  deregulation

# %%
tsne = TSNE(n_components=2).fit(scaled_data_frame)

X_embedded = tsne.fit_transform(scaled_data_frame)
X_embedded.shape
# Out:
# (3823, 2)

# %%
plt.figure(figsize=(12,8))
plt.title('t-SNE components')
plt.scatter(X_embedded[:,0], X_embedded[:,1], c = target)
plt.xlabel("tsne-2d-one")
plt.ylabel("tsne-2d-two")
plt.colorbar()

# %% [markdown]
# #### (Extra analysis) Feature Selection for iterating over again (when needed to reproduce for a better projection estimate)
# 1. trying to do feature importance using Random Forest classifier
#
# 2. Select some features based on feature importances indicated by an unparameterized (to avoid overfitting) and hence, sub-optimal random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier().fit(features,target)

# %%
# print importances
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]
# Print the feature ranking
print("Feature ranking:")
for f in range(features.shape[1]):
    print( (f + 1, features.columns[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# (1, 'regions', 0.028124237347481568)
# (2, 'corrupt_salience', 0.026695116127790214)
# (3, 'eu_salience', 0.025609445400803538)
# (4, 'people_vs_elite', 0.02546554430728286)
# (5, 'religious_principles', 0.024887712261953784)
# (6, 'urban_rural', 0.024602033361564253)
# (7, 'lrgen', 0.024431106889487273)
# (8, 'enviro_salience', 0.023947274587262958)
# (9, 'antielite_salience', 0.02388635681355972)
# (10, 'members_vs_leadership', 0.02368929419226694)
# (11, 'position', 0.023367966604943557)
# (12, 'lrecon', 0.022973897540615233)
# (13, 'lrecon_salience', 0.02272590129216522)
# (14, 'russian_interference', 0.02186035485277255)
# (15, 'ethnic_minorities', 0.021686366558376097)
# (16, 'galtan', 0.02144966966586933)
# (17, 'lrecon_self', 0.0213837581051774)
# (18, 'immigra_salience', 0.021267699064835843)
# (19, 'sociallifestyle', 0.020905830279588578)
# (20, 'immigrate_policy', 0.020876801580771195)
# (21, 'environment', 0.02077255905113762)
# (22, 'redistribution', 0.02047877175242636)
# (23, 'galtan_salience', 0.020473874675799964)
# (24, 'spendvtax', 0.02028918923059917)
# (25, 'nationalism', 0.020283284225906927)
# (26, 'econ_interven', 0.020168866742493106)
# (27, 'redist_salience', 0.02014260264310552)
# (28, 'deregulation', 0.019707600681004328)
# (29, 'protectionism', 0.019409257116551188)
# (30, 'civlib_laworder', 0.01924578429580527)
# (31, 'galtan_self', 0.01870474925380876)
# (32, 'multicult_salience', 0.018624734459679375)
# (33, 'immigrate_dissent', 0.018426651369873783)
# (34, 'multiculturalism', 0.018166199429915236)
# (35, 'dob_bins', 0.01705481277692207)
# (36, 'eu_budgets', 0.01703824541008976)
# (37, 'eu_foreign', 0.01672637511408883)
# (38, 'multicult_dissent', 0.01647649298284728)
# (39, 'anti_islam_rhetoric', 0.016458599323191776)
# (40, 'eu_asylum', 0.015753843582726315)
# (41, 'eu_cohesion', 0.01549220961956295)
# (42, 'eu_blur', 0.01505543911533366)
# (43, 'eu_intmark', 0.014838605539374373)
# (44, 'party_c_econ', 0.014362629894029321)
# (45, 'lrecon_blur', 0.014091575161673421)
# (46, 'galtan_dissent', 0.013322178492215016)
# (47, 'galtan_blur', 0.012852075721122094)
# (48, 'lrecon_dissent', 0.012670535615237098)
# (49, 'party_b_econ', 0.012283138899459341)
# (50, 'eu_dissent', 0.012153962887497195)
# (51, 'party_a_econ', 0.01114593337102756)
# (52, 'gender', 0.007492854730927228)

# %% [markdown]
# # Part III Fitting a distribution

# %% [markdown]
# #### Kernel Density Estimation 2D
# * For estimating a distribution of the 2D points from the dimensionality reduction you need to see the probability distribution of those points

# %%
def kde2D(x, y, bandwidth, xbins=128j, ybins=128j, **kwargs): 
    """Build 2D kernel density estimate (KDE)."""

    # create grid of sample locations (default: 100x100)
    xx, yy = np.mgrid[x.min():x.max():xbins, 
                      y.min():y.max():ybins]

    xy_sample = np.vstack([yy.ravel(), xx.ravel()]).T
    xy_train  = np.vstack([y, x]).T

    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(xy_train)
    
    # score_samples() returns the log-likelihood of the samples
    z = np.exp(kde_skl.score_samples(xy_sample))
    return xx, yy, np.reshape(z, xx.shape)

# %%
# use grid search cross-validation to optimize the bandwidth
params = {'bandwidth': np.logspace(-1, 1, 20)}
grid = GridSearchCV(KernelDensity(), params)
grid.fit(df_pca_2)
# Out:
# GridSearchCV(estimator=KernelDensity(),
#              param_grid={'bandwidth': array([ 0.1       ,  0.1274275 ,  0.16237767,  0.20691381,  0.26366509,
#         0.33598183,  0.42813324,  0.54555948,  0.6951928 ,  0.88586679,
#         1.12883789,  1.43844989,  1.83298071,  2.33572147,  2.97635144,
#         3.79269019,  4.83293024,  6.15848211,  7.8475997 , 10.        ])})

# %%
print("best bandwidth: {0}".format(grid.best_estimator_.bandwidth))
# Out:
# best bandwidth: 0.5455594781168519

# %%
x_ax, y_ax = df_pca_2[:,1] + df_pca_2[:,0], df_pca_2[:,0] - df_pca_2[:,1]
xx, yy, zz = kde2D(x_ax, y_ax, grid.best_estimator_.bandwidth)

# %%
plt.pcolormesh(xx, yy, zz, shading="auto")
plt.scatter(x_ax, y_ax, s=2, facecolor='white')

# %%
kde = grid.best_estimator_

# %%
kde
# Out:
# KernelDensity(bandwidth=0.5455594781168519)

# %%
plt.rcParams['figure.dpi'] = 200

# %% [markdown]
# ### Fitting and contouring a Gaussian Kernel Density Estimation

# %%
# Extract x and y
xaxis = df_pca_2[:, 0]
yaxis = df_pca_2[:, 1]
# Define the borders
deltaX = (max(xaxis) - min(xaxis))/10
deltaY = (max(yaxis) - min(yaxis))/10
xmin = min(xaxis) - deltaX
xmax = max(xaxis) + deltaX
ymin = min(yaxis) - deltaY
ymax = max(yaxis) + deltaY
print(xmin, xmax, ymin, ymax)
# Create meshgrid
x_x, y_y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
# Out:
# -9.317797238576885 11.410783701330857 -7.687659775227082 9.250576973595452

# %%
positions = np.vstack([x_x.ravel(), y_y.ravel()])
values = np.vstack([xaxis, yaxis])
kernel = stats.gaussian_kde(values)
f = np.reshape(kernel(positions).T, x_x.shape)

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.gca()
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
cfset = ax.contourf(x_x, y_y, f, cmap='coolwarm')
ax.imshow(np.rot90(f), cmap='coolwarm', extent=[xmin, xmax, ymin, ymax])
cset = ax.contour(x_x, y_y, f, colors='k')
ax.clabel(cset, inline=1, fontsize=10)
ax.set_xlabel('X')
ax.set_ylabel('Y')
plt.title('2D Gaussian Kernel density estimation')
# Out:
# Text(0.5, 1.0, '2D Gaussian Kernel density estimation')

# %% [markdown]
# #### Rendering the distribution in 3D

# %%
fig = plt.figure(figsize=(13, 7))
ax = plt.axes(projection='3d')
surf = ax.plot_surface(x_x, y_y, f, rstride=1, cstride=1, cmap='coolwarm', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('PDF')
ax.set_title('Surface plot of Gaussian 2D KDE')
fig.colorbar(surf, shrink=0.5, aspect=5) # add color bar indicating the PDF
ax.view_init(60, 35)

# %% [markdown]
# # Part IV Random Sampling

# %%
#sampling using kde
z = kde.fit(df_pca_2)
sampled_data = z.sample(10, random_state=0)
sampled_data = pca_2.inverse_transform(sampled_data)

# %%
sampled_data
# Out:
# array([[ 4.37036278e-01,  1.74365873e-01, -3.95446236e-02,
#         -1.07937957e-01,  7.91628607e-01, -2.34579713e-02,
#          4.39338231e-02,  8.87785112e-02,  6.65137571e-02,
#          1.58202402e-01,  1.16992181e-01, -9.15673860e-02,
#          5.10929921e-01,  1.26079674e-01, -1.41931035e-01,
#          2.01011257e-01,  1.33892189e-01, -1.19538951e-01,
#          1.88287187e-01,  7.72049668e-01, -3.21990853e-01,
#          2.99075494e-01, -1.86497549e-01,  7.43374357e-01,
#          8.24751698e-01,  8.21383672e-01,  1.00968626e-01,
#          3.59473032e-02,  1.64133991e-01,  9.38256223e-02,
#         -5.70361563e-03, -6.76770922e-02, -6.41434787e-01,
#         -6.58906740e-02,  6.34546790e-02, -1.13823951e-01,
#         -3.93965648e-01, -4.33596582e-01, -1.11984043e-01,
#          8.08325527e-02,  1.81760462e-01,  4.40943739e-01,
#          5.63126756e-01,  4.80168654e-01,  2.40456448e-01,
#          1.33486623e-02,  2.93060559e-03, -5.82793207e-03,
#         -2.37134781e-02,  4.33113005e-02, -2.37800357e-02,
#          1.61305489e-02],
#        [-1.43290751e+00, -3.46103462e-01,  7.39386565e-02,
#          3.81897434e-01, -2.87708030e-01,  3.03833807e-01,
#          1.77076889e-03, -4.66702586e-01,  1.21567725e+00,
#         -1.37968064e-01, -1.47479897e-01,  3.37660975e-01,
#          5.27338312e-01,  1.15474721e+00,  9.06485801e-01,
#         -5.35640649e-01,  1.08287910e+00,  6.00329607e-01,
#         -4.97206164e-01, -2.82078816e-01,  2.47828143e-02,
#          6.55031122e-01, -6.04061493e-01, -1.53306281e-01,
#         -4.62840483e-01, -4.94073936e-01,  1.15473353e+00,
#          1.21566828e+00,  8.20770024e-01,  1.13221290e+00,
#          1.33159392e+00,  8.49132806e-01,  1.25794872e+00,
#          5.21571564e-01,  7.85473285e-02,  1.09381048e+00,
#          7.32373679e-01,  1.16752650e+00,  1.40945921e-01,
#          6.38123149e-01, -7.13766346e-01, -1.35499368e+00,
#         -1.25882659e+00, -1.32388742e+00, -1.37943448e+00,
#          3.92786892e-02, -4.70057727e-02, -3.62803649e-02,
#          6.62145110e-02, -3.19776254e-02, -1.01834431e-02,
#         -6.39876074e-02],
#        [ 2.75413007e-01, -5.13557541e-02,  1.49023448e-02,
#         -8.80350423e-02, -1.15061543e+00, -1.76974340e-01,
#         -7.65350194e-02,  1.81473880e-01, -9.82853076e-01,
#         -1.72427434e-01, -9.50257246e-02, -8.44640596e-02,
#         -1.25225999e+00, -1.04135462e+00, -4.04743304e-01,
#          3.84648775e-02, -1.00337203e+00, -2.24282925e-01,
#          3.27934767e-02, -1.12109538e+00,  5.33935610e-01,
#         -9.80569349e-01,  7.51265558e-01, -1.16400704e+00,
#         -1.08218840e+00, -1.05409421e+00, -9.98323488e-01,
#         -9.30478861e-01, -8.67842574e-01, -9.69989277e-01,
#         -9.41977889e-01, -4.90965703e-01,  1.99822421e-01,
#         -2.59903642e-01, -1.64854647e-01, -5.86786913e-01,
#          1.51499260e-01, -9.16263975e-02,  9.11156862e-02,
#         -5.94580991e-01,  1.98760574e-01,  2.13030083e-01,
#         -6.50341854e-02,  1.23595186e-01,  5.73982724e-01,
#         -5.09437509e-02,  2.85762794e-02,  3.59158666e-02,
#         -6.69948370e-03, -5.13470031e-02,  4.80195717e-02,
#          1.80992266e-02],
#        [ 2.03543350e-01, -9.26919189e-03,  3.92886654e-03,
#         -6.15014367e-02, -5.56907031e-01, -1.01937725e-01,
#         -3.80214779e-02,  1.11785892e-01, -5.44063329e-01,
#         -7.90197632e-02, -4.02065978e-02, -5.76622526e-02,
#         -6.45414075e-01, -5.70212902e-01, -2.43030892e-01,
#          4.41202552e-02, -5.48023378e-01, -1.39256503e-01,
#          3.95112581e-02, -5.42537135e-01,  2.63514451e-01,
#         -5.16708625e-01,  4.00658037e-01, -5.69831559e-01,
#         -5.14796202e-01, -4.99408962e-01, -5.48881590e-01,
#         -5.18100842e-01, -4.68581574e-01, -5.33782891e-01,
#         -5.29223045e-01, -2.83089087e-01,  4.02155867e-02,
#         -1.53230120e-01, -8.53928096e-02, -3.42032082e-01,
#          4.08439418e-02, -1.00027283e-01,  3.85739876e-02,
#         -3.24582132e-01,  1.31910678e-01,  1.68975733e-01,
#          2.66404347e-02,  1.23187659e-01,  3.49044267e-01,
#         -2.70901318e-02,  1.63639169e-02,  1.95005230e-02,
#         -6.41795398e-03, -2.39572106e-02,  2.42797581e-02,
#          1.19646860e-02],
#        [ 1.63360738e+00,  4.40798749e-01, -9.57099001e-02,
#         -4.29650773e-01,  8.00825437e-01, -2.99898584e-01,
#          2.78559088e-02,  4.96089260e-01, -1.09220434e+00,
#          2.35295923e-01,  2.16508887e-01, -3.77284776e-01,
#         -1.49949508e-01, -9.95210894e-01, -9.43072670e-01,
#          6.35949865e-01, -9.22752923e-01, -6.41718218e-01,
#          5.91459275e-01,  7.82409209e-01, -2.39469205e-01,
#         -4.11676128e-01,  4.39632657e-01,  6.42720753e-01,
#          9.86856759e-01,  1.01380341e+00, -1.01206608e+00,
#         -1.11272852e+00, -6.57317772e-01, -9.95803317e-01,
#         -1.24911892e+00, -8.39557963e-01, -1.60729015e+00,
#         -5.32027371e-01, -3.08315811e-02, -1.09937551e+00,
#         -9.49546087e-01, -1.38311628e+00, -2.07034263e-01,
#         -5.42465554e-01,  7.89599029e-01,  1.56336826e+00,
#          1.55550884e+00,  1.56062689e+00,  1.45155053e+00,
#         -2.77660989e-02,  4.59277183e-02,  3.00140500e-02,
#         -7.78520481e-02,  5.89987542e-02, -6.45048270e-03,
#          7.06757572e-02],
#        [-8.12591766e-01, -1.30734566e-01,  2.57434123e-02,
#          2.24706545e-01,  5.07307258e-01,  2.38227766e-01,
#          4.33669069e-02, -3.15686587e-01,  1.10593837e+00,
#          3.23691163e-02, -1.50423264e-02,  2.02362186e-01,
#          9.38928726e-01,  1.11042221e+00,  6.42221550e-01,
#         -2.67903826e-01,  1.05622875e+00,  4.00986783e-01,
#         -2.47061921e-01,  4.93485431e-01, -2.85451751e-01,
#          8.46642261e-01, -6.95696150e-01,  5.76608498e-01,
#          3.88661911e-01,  3.58667514e-01,  1.08649146e+00,
#          1.07681522e+00,  8.60246505e-01,  1.06037352e+00,
#          1.13656096e+00,  6.63763892e-01,  4.67848986e-01,
#          3.84544344e-01,  1.27805767e-01,  8.29646686e-01,
#          2.52830077e-01,  5.88273660e-01,  1.42090952e-02,
#          6.24258864e-01, -4.39003902e-01, -7.42049790e-01,
#         -5.43192579e-01, -6.78009721e-01, -9.53980665e-01,
#          4.64009577e-02, -3.75213282e-02, -3.66658335e-02,
#          3.41987116e-02,  1.38308342e-02, -3.13846549e-02,
#         -3.95118526e-02],
#        [ 1.40728445e+00,  4.04369004e-01, -8.85355087e-02,
#         -3.67067722e-01,  9.41940798e-01, -2.33565101e-01,
#          3.99230939e-02,  4.08177962e-01, -7.84290242e-01,
#          2.44281706e-01,  2.12300908e-01, -3.20925808e-01,
#          1.11389198e-01, -6.86058430e-01, -7.64235589e-01,
#          5.61323719e-01, -6.28690809e-01, -5.30051675e-01,
#          5.22638269e-01,  9.19679479e-01, -3.18892873e-01,
#         -1.75996871e-01,  2.45962163e-01,  8.03139739e-01,
#          1.09493222e+00,  1.11352813e+00, -7.09572393e-01,
#         -8.12917990e-01, -4.17827909e-01, -7.00580413e-01,
#         -9.32666410e-01, -6.54735408e-01, -1.47691909e+00,
#         -4.24947942e-01,  4.74253554e-03, -8.68358582e-01,
#         -8.79084323e-01, -1.21925060e+00, -2.03059125e-01,
#         -3.68667428e-01,  6.67336909e-01,  1.35668560e+00,
#          1.40417316e+00,  1.37176822e+00,  1.18589403e+00,
#         -1.48489806e-02,  3.54801971e-02,  1.98062025e-02,
#         -6.83261297e-02,  6.28423449e-02, -1.51848650e-02,
#          5.96717869e-02],
#        [ 6.09267297e-01,  1.17321391e-01, -2.40684119e-02,
#         -1.66085545e-01, -1.82940487e-01, -1.59206105e-01,
#         -2.00413314e-02,  2.21671812e-01, -7.06557255e-01,
#          8.30115595e-03,  3.14767099e-02, -1.48524752e-01,
#         -5.15569270e-01, -6.98424094e-01, -4.43787788e-01,
#          2.11427559e-01, -6.61747694e-01, -2.82824733e-01,
#          1.95519730e-01, -1.77587217e-01,  1.25832154e-01,
#         -4.94873254e-01,  4.17633700e-01, -2.36938205e-01,
#         -9.96739959e-02, -8.08013965e-02, -6.87525765e-01,
#         -6.93295533e-01, -5.28744258e-01, -6.71873134e-01,
#         -7.39857151e-01, -4.44018962e-01, -4.23084114e-01,
#         -2.62186409e-01, -7.13086000e-02, -5.60406774e-01,
#         -2.37416741e-01, -4.62815719e-01, -3.00062165e-02,
#         -3.90795152e-01,  3.19077350e-01,  5.64137584e-01,
#          4.57535823e-01,  5.29784698e-01,  6.64714398e-01,
#         -2.76862388e-02,  2.49335523e-02,  2.27529937e-02,
#         -2.66283849e-02, -9.57443509e-04,  1.59904593e-02,
#          2.86756698e-02],
#        [-6.42678540e-01, -7.39663567e-02,  1.30914310e-02,
#          1.81373636e-01,  7.02317607e-01,  2.18019829e-01,
#          5.33228860e-02, -2.72589462e-01,  1.06174211e+00,
#          7.52727762e-02,  1.89061641e-02,  1.64932774e-01,
#          1.02995167e+00,  1.08281882e+00,  5.65486105e-01,
#         -1.95783827e-01,  1.03392277e+00,  3.44329109e-01,
#         -1.79728398e-01,  6.83745323e-01, -3.60264149e-01,
#          8.82999699e-01, -7.08810709e-01,  7.54021664e-01,
#          5.99800899e-01,  5.70562751e-01,  1.05314880e+00,
#          1.02563245e+00,  8.57660386e-01,  1.02649849e+00,
#          1.07019318e+00,  6.06803966e-01,  2.59762638e-01,
#          3.43997983e-01,  1.38472434e-01,  7.50183013e-01,
#          1.26991362e-01,  4.32113673e-01, -1.82753612e-02,
#          6.11555944e-01, -3.62580761e-01, -5.75050394e-01,
#         -3.52963180e-01, -5.03564104e-01, -8.31614930e-01,
#          4.75330018e-02, -3.45546581e-02, -3.62252739e-02,
#          2.55428681e-02,  2.52935217e-02, -3.63227733e-02,
#         -3.26981443e-02],
#        [ 8.03347374e-01,  2.60234552e-01, -5.78018564e-02,
#         -2.05890873e-01,  8.38479800e-01, -1.03755875e-01,
#          4.17941864e-02,  2.10119029e-01, -2.60851372e-01,
#          1.89068142e-01,  1.51962744e-01, -1.78320797e-01,
#          3.50639145e-01, -1.87263700e-01, -3.78770262e-01,
#          3.36515638e-01, -1.60543584e-01, -2.75419277e-01,
#          3.14004096e-01,  8.18139329e-01, -3.16399552e-01,
#          1.12699730e-01, -1.80116536e-02,  7.56142290e-01,
#          9.17143784e-01,  9.22249429e-01, -2.11418597e-01,
#         -2.90256003e-01, -6.14105000e-02, -2.12272900e-01,
#         -3.61303638e-01, -2.92007526e-01, -9.53241889e-01,
#         -2.02760944e-01,  4.00590593e-02, -4.01784509e-01,
#         -5.74720217e-01, -7.29125460e-01, -1.45398623e-01,
#         -9.27469740e-02,  3.65592173e-01,  7.86287199e-01,
#          8.78138761e-01,  8.15712329e-01,  5.99935504e-01,
#          2.34663720e-03,  1.53798972e-02,  4.08763693e-03,
#         -4.05072316e-02,  5.02132147e-02, -2.01569009e-02,
#          3.26168801e-02]])

# %%
# feature values from the high-dimensional space that map to the sampled_data
pd.DataFrame(sampled_data,columns= features.columns)
# Out:
#    position  eu_salience  eu_dissent   eu_blur    lrecon  lrecon_blur  \
# 0  0.437036     0.174366   -0.039545 -0.107938  0.791629    -0.023458
# 1 -1.432908    -0.346103    0.073939  0.381897 -0.287708     0.303834
# 2  0.275413    -0.051356    0.014902 -0.088035 -1.150615    -0.176974
# 3  0.203543    -0.009269    0.003929 -0.061501 -0.556907    -0.101938
# 4  1.633607     0.440799   -0.095710 -0.429651  0.800825    -0.299899
# 5 -0.812592    -0.130735    0.025743  0.224707  0.507307     0.238228
# 6  1.407284     0.404369   -0.088536 -0.367068  0.941941    -0.233565
# 7  0.609267     0.117321   -0.024068 -0.166086 -0.182940    -0.159206
# 8 -0.642679    -0.073966    0.013091  0.181374  0.702318     0.218020
# 9  0.803347     0.260235   -0.057802 -0.205891  0.838480    -0.103756
#
#    lrecon_dissent  lrecon_salience    galtan  galtan_blur  ...  eu_intmark  \
# 0        0.043934         0.088779  0.066514     0.158202  ...    0.563127
# 1        0.001771        -0.466703  1.215677    -0.137968  ...   -1.258827
# 2       -0.076535         0.181474 -0.982853    -0.172427  ...   -0.065034
# 3       -0.038021         0.111786 -0.544063    -0.079020  ...    0.026640
# 4        0.027856         0.496089 -1.092204     0.235296  ...    1.555509
# 5        0.043367        -0.315687  1.105938     0.032369  ...   -0.543193
# 6        0.039923         0.408178 -0.784290     0.244282  ...    1.404173
# 7       -0.020041         0.221672 -0.706557     0.008301  ...    0.457536
# 8        0.053323        -0.272589  1.061742     0.075273  ...   -0.352963
# 9        0.041794         0.210119 -0.260851     0.189068  ...    0.878139
#
#    eu_budgets  eu_asylum  party_a_econ  party_b_econ  party_c_econ  \
# 0    0.480169   0.240456      0.013349      0.002931     -0.005828
# 1   -1.323887  -1.379434      0.039279     -0.047006     -0.036280
# 2    0.123595   0.573983     -0.050944      0.028576      0.035916
# 3    0.123188   0.349044     -0.027090      0.016364      0.019501
# 4    1.560627   1.451551     -0.027766      0.045928      0.030014
# 5   -0.678010  -0.953981      0.046401     -0.037521     -0.036666
# 6    1.371768   1.185894     -0.014849      0.035480      0.019806
# 7    0.529785   0.664714     -0.027686      0.024934      0.022753
# 8   -0.503564  -0.831615      0.047533     -0.034555     -0.036225
# 9    0.815712   0.599936      0.002347      0.015380      0.004088
#
#    lrecon_self  galtan_self    gender  dob_bins
# 0    -0.023713     0.043311 -0.023780  0.016131
# 1     0.066215    -0.031978 -0.010183 -0.063988
# 2    -0.006699    -0.051347  0.048020  0.018099
# 3    -0.006418    -0.023957  0.024280  0.011965
# 4    -0.077852     0.058999 -0.006450  0.070676
# 5     0.034199     0.013831 -0.031385 -0.039512
# 6    -0.068326     0.062842 -0.015185  0.059672
# 7    -0.026628    -0.000957  0.015990  0.028676
# 8     0.025543     0.025294 -0.036323 -0.032698
# 9    -0.040507     0.050213 -0.020157  0.032617
#
# [10 rows x 52 columns]

# %%
np.mean(scaled_data_frame[0])
# Out:
# 0.2255373520823562

# %%
#vizualizing the sampled data
x_axis, y_axis = z.sample(10, random_state=0)[:,1] + z.sample(10, random_state=0)[:,0], z.sample(10, random_state=0)[:,0] - z.sample(10, random_state=0)[:,1]
xx_1, yy_1, zz_1 = kde2D(x_ax, y_ax, grid.best_estimator_.bandwidth)

# %%
plt.pcolormesh(xx_1, yy_1, zz_1, shading="auto")
plt.scatter(x_axis, y_axis, s=1,facecolor='white')
